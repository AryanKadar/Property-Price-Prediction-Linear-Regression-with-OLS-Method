# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as mp
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif 
from sklearn.model_selection import train_test_split as TTS
from sklearn.linear_model import LinearRegression as LR
from sklearn.preprocessing import StandardScaler as SS
from sklearn.pipeline import make_pipeline as MKP
from sklearn.model_selection import cross_val_score as CVS

# %%
t=pd.read_csv('HousePrices.csv')

# %%
t.head()
# Out:
#    Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0   1          60         RL         65.0     8450      Pave   NaN
# 1   2          20         RL         80.0     9600      Pave   NaN
# 2   3          60         RL         68.0    11250      Pave   NaN
# 3   4          70         RL         60.0     9550      Pave   NaN
# 4   5          60         RL         84.0    14260      Pave   NaN
#
#   Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  Property_Sale_Price
# ...

# %%
t["Dwell_Type"].dtypes
# Out:
# dtype('int64')

# %%
coll=[i for i in t.columns if t[i].dtypes=="float64" or t[i].dtypes=="int64"]

# %%
coll
# Out:
# ['Id',
#  'Dwell_Type',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'Property_Sale_Price']

# %%
t1=t[coll]

# %%
kol=[i for i in t1.columns if t1[i].unique().sum()<11]

# %%
kk=t1[kol]

# %%
kk["Property_Sale_Price"]=t1["Property_Sale_Price"]
# Out:
# C:\Users\AryanBr0\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sn.pairplot(kk)

# %%
kol=[i for i in t1.columns if len(t1[i].unique())>20 or "YrSold" in i]

# %%
kol
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'MiscVal',
#  'YrSold',
#  'Property_Sale_Price']

# %%
t1=t1[kol]

# %%
kol=[i for i in t1.columns if "Y" in i]

# %%
t1[kol]
# Out:
#       YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0          2003          2003       2003.0    2008
# 1          1976          1976       1976.0    2007
# 2          2001          2002       2001.0    2008
# 3          1915          1970       1998.0    2006
# 4          2000          2000       2000.0    2008
# ...         ...           ...          ...     ...
# 2068       1936          1999       1999.0    2009
# 2069       1936          1977          NaN    2007
# 2070       1983          1996       2017.0    2007
# 2071       1958          1958       1958.0    2009
# 2072       1890          1996       1963.0    2009
#
# [2073 rows x 4 columns]

# %%
kk1=pd.DataFrame()
kk1["Age"]=t1["YrSold"]-t1["YearBuilt"]

# %%
kk1["YearRemodAdd"]=t1["YrSold"]-t1["YearRemodAdd"]

# %%
kk1["GarageYrBlt"]=t1["YrSold"]-t1["GarageYrBlt"]

# %%
kk1["Property_Sale_Price"]=t1["Property_Sale_Price"]

# %%
sn.pairplot(kk1)

# %%
kol=[i for i in t1.columns if "Y" not in i]
kol
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'MiscVal',
#  'Property_Sale_Price']

# %%
t1=t1[kol]

# %%
kol=[i for i in t1.columns if t1[(t1[i]==0)][i].count()>len(t1)/2]

# %%
kk=t1[kol]

# %%
kk["Property_Sale_Price"]=t1["Property_Sale_Price"]
# Out:
# C:\Users\AryanBr0\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sn.pairplot(kk)

# %%
kol=[i for i in t1.columns if t1[(t1[i]==0)][i].count()<len(t1)/2]

# %%
t1=t1[kol]

# %%
t1.drop("Id",axis=1,inplace=True)

# %%
t1.dropna(inplace=True)
t1.isnull().sum()
# Out:
# LotFrontage            0
# LotArea                0
# BsmtFinSF1             0
# BsmtUnfSF              0
# TotalBsmtSF            0
# 1stFlrSF               0
# GrLivArea              0
# GarageArea             0
# OpenPorchSF            0
# Property_Sale_Price    0
# dtype: int64

# %%
for i in t1.columns:
    sn.lmplot(data=t1,x=i,y="Property_Sale_Price")

# %%
def VIF(kk):
    return [(j,vif(kk.values,i)) for i,j in enumerate(kk.columns[:kk.shape[1]-1])]

# %%
VIF(t1)
# Out:
# [('LotFrontage', 8.625636515357755),
#  ('LotArea', 3.219692240816888),
#  ('BsmtFinSF1', 16.458480880940566),
#  ('BsmtUnfSF', 21.71762895270716),
#  ('TotalBsmtSF', 67.18655936999535),
#  ('1stFlrSF', 33.58975651914485),
#  ('GrLivArea', 19.74566666532571),
#  ('GarageArea', 9.77393247522361),
#  ('OpenPorchSF', 1.7839074087977165)]

# %%
kk=t1.corr()
sn.heatmap(kk,annot=True);

# %%
t1.drop("TotalBsmtSF",axis=1,inplace=True)

# %%
VIF(t1)
# Out:
# [('LotFrontage', 8.608231914481024),
#  ('LotArea', 3.2069118923696744),
#  ('BsmtFinSF1', 6.0653757024064525),
#  ('BsmtUnfSF', 7.593508684721566),
#  ('1stFlrSF', 27.384081546387673),
#  ('GrLivArea', 19.265598388730254),
#  ('GarageArea', 9.773752550955153),
#  ('OpenPorchSF', 1.7712822360394298)]

# %%
t1.drop("1stFlrSF",axis=1,inplace=True)

# %%
VIF(t1)
# Out:
# [('LotFrontage', 7.957085147869691),
#  ('LotArea', 3.177429516856443),
#  ('BsmtFinSF1', 3.9786895433143226),
#  ('BsmtUnfSF', 4.9834127922974645),
#  ('GrLivArea', 16.79971454731876),
#  ('GarageArea', 9.588557974997897),
#  ('OpenPorchSF', 1.7532642326725312)]

# %%
t1.drop("OpenPorchSF",axis=1,inplace=True)

# %%
t1.drop("LotArea",axis=1,inplace=True)

# %%
t1.drop("BsmtUnfSF",axis=1,inplace=True)

# %%
t1.drop("BsmtFinSF1",axis=1,inplace=True)

# %%
t1.drop("LotFrontage",axis=1,inplace=True)

# %%
for i in t1.columns:
    sn.lmplot(data=t1,x=i,y="Property_Sale_Price")

# %%
VIF(t1)
# Out:
# [('GrLivArea', 12.644760882920957), ('GarageArea', 8.735081385292258)]

# %%
x=t1.iloc[:,:t1.shape[1]-1]
x
# Out:
#       GrLivArea  GarageArea
# 0          1710         548
# 1          1262         460
# 2          1786         608
# 3          1717         642
# 4          2198         836
# ...         ...         ...
# 2067       1728         574
# 2069       1440           0
# 2070       1632         576
# 2071       1344         525
# 2072       1869         456
#
# [1753 rows x 2 columns]

# %%
y=t1.iloc[:,-1]
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 2067    150900
# 2069    150000
# 2070    143000
# 2071    137500
# 2072    124900
# Name: Property_Sale_Price, Length: 1753, dtype: int64

# %%
xtrain,xtest,ytrain,ytest=TTS(x,y,test_size=0.2,random_state=2)

# %%
mkp=MKP(SS(),LR())

# %%
mkp.fit(xtest,ytest)
# Out:
# Pipeline(memory=None,
#          steps=[('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('linearregression',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
mkp.score(xtrain,ytrain)
# Out:
# 0.6058153164622341

# %%
CVS(mkp,xtrain,ytrain,cv=6,scoring="r2")
# Out:
# array([0.60588383, 0.65417816, 0.62168594, 0.68704089, 0.6873727 ,
#        0.25707172])

# %%
mkp.named_steps["linearregression"].coef_
# Out:
# array([39279.26253887, 31628.12281995])

# %%
mkp.named_steps["linearregression"].intercept_
# Out:
# 179755.51566951568
